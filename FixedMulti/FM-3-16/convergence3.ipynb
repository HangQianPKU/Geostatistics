# %%
import math
import numpy as np
import statsmodels.api as sm
from statsmodels.base.model import GenericLikelihoodModel
from scipy.stats import poisson
from patsy import dmatrices
import statsmodels.graphics.tsaplots as tsa
from matplotlib import pyplot as plt
from statsmodels.tools.numdiff import approx_hess1, approx_hess2, approx_hess3
import pandas as pd
import pymc as pm
import sys
import arviz as az
import pickle

with open('trace', 'rb') as f:
    loaded_data = pickle.load(f)

switchpoints = np.array(loaded_data.posterior.switchpoints)
np.shape(switchpoints)
# Out:
# (4, 80000, 3)

# %%
loaded_data
# Out:
# Inference data with groups:
# 	> posterior
# 	> sample_stats
# 	> observed_data

# %%
switchpoints = loaded_data.posterior.switchpoints

# 计算自相关
autocorr = az.plot_autocorr(switchpoints, combined=False)

# 绘制自相关图
az.plot_autocorr(autocorr)

# 添加参考线
#plt.hlines([0], [0], len(theta))  
#plt.axvline(len(theta) / 10)

# 保存图片
#plt.savefig('autocorr_pymc4.png')
# Out:
# /lustre/home/hangqian/miniconda3/envs/pymc_env5/lib/python3.11/site-packages/arviz/data/base.py:221: UserWarning: More chains (4) than draws (3). Passed array should have shape (chains, draws, *shape)
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 autocorr = az.plot_autocorr(switchpoints, combined=False)
#       6 # 绘制自相关图
# ----> 7 az.plot_autocorr(autocorr)
#       9 # 添加参考线
#      10 #plt.hlines([0], [0], len(theta))
#      11 #plt.axvline(len(theta) / 10)
#      12
#      13 # 保存图片
#      14 #plt.savefig('autocorr_pymc4.png')
#
# File ~/miniconda3/envs/pymc_env5/lib/python3.11/site-packages/arviz/plots/autocorrplot.py:158, in plot_autocorr(data, var_names, filter_vars, max_lag, combined, grid, figsize, textsize, labeller, ax, backend, backend_config, backend_kwargs, show)
#     156 # TODO: Add backend kwargs
# ...
