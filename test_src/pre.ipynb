# %%
import pandas as pd
from matplotlib import pyplot as plt

def process_data():
    # 加载数据
    df = pd.read_csv('/lustre/home/hangqian/projects/data/zircons/Roberts_Spencer_2015.csv')
    years = df["U-Pb (Ma)"]

    # 绘制直方图
    data = plt.hist(years, bins=200)
    zircons_data = data[0]
    ages = data[1][1:]

    return ages, zircons_data

def process_data_early():
    # 加载数据
    df = pd.read_csv('/lustre/home/hangqian/projects/data/zircons/Roberts_Spencer_2015.csv')
    years = df["U-Pb (Ma)"]

    # 绘制直方图
    data = plt.hist(years, bins=400)
    zircons_data = data[0][:230]
    ages = data[1][1:][:230]

    return ages, zircons_data

def process_data_late():
    # 加载数据
    df = pd.read_csv('/lustre/home/hangqian/projects/data/zircons/Roberts_Spencer_2015.csv')
    years = df["U-Pb (Ma)"]

    # 绘制直方图
    data = plt.hist(years, bins=400)
    zircons_data = data[0][230:]
    ages = data[1][1:][230:]

    return ages, zircons_data


if __name__ == "__main__":

    #调试 process_data()
    #ages, zircons_data = process_data()
    #print(ages)
    #print(zircons_data)
    #print(len(ages))
    #print(len(zircons_data))

    #调试 process_data_early()
    #ages, zircons_data = process_data_early()
    #print(ages)
    #print(zircons_data)
    #print(len(ages))
    #print(len(zircons_data))

    #调试 process_data_late()
    ages, zircons_data = process_data_late()
    print(ages)
    print(zircons_data)
    print(len(ages))
    print(len(zircons_data))
# Out:
# [2516.745 2527.64  2538.535 2549.43  2560.325 2571.22  2582.115 2593.01
#  2603.905 2614.8   2625.695 2636.59  2647.485 2658.38  2669.275 2680.17
#  2691.065 2701.96  2712.855 2723.75  2734.645 2745.54  2756.435 2767.33
#  2778.225 2789.12  2800.015 2810.91  2821.805 2832.7   2843.595 2854.49
#  2865.385 2876.28  2887.175 2898.07  2908.965 2919.86  2930.755 2941.65
#  2952.545 2963.44  2974.335 2985.23  2996.125 3007.02  3017.915 3028.81
#  3039.705 3050.6   3061.495 3072.39  3083.285 3094.18  3105.075 3115.97
#  3126.865 3137.76  3148.655 3159.55  3170.445 3181.34  3192.235 3203.13
#  3214.025 3224.92  3235.815 3246.71  3257.605 3268.5   3279.395 3290.29
#  3301.185 3312.08  3322.975 3333.87  3344.765 3355.66  3366.555 3377.45
#  3388.345 3399.24  3410.135 3421.03  3431.925 3442.82  3453.715 3464.61
#  3475.505 3486.4   3497.295 3508.19  3519.085 3529.98  3540.875 3551.77
#  3562.665 3573.56  3584.455 3595.35  3606.245 3617.14  3628.035 3638.93
# ...
